# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("Train_dataset.csv")
df
# Out:
#        people_ID        Region  Gender Designation  \
# 0              1  Bhubaneshwar  Female         Mrs
# 1              2  Bhubaneshwar  Female         Mrs
# 2              3  Bhubaneshwar  Female         Mrs
# 3              4  Bhubaneshwar  Female         Mrs
# 4              5  Bhubaneshwar  Female         Mrs
# 5              6  Bhubaneshwar  Female         Mrs
# 6              7  Bhubaneshwar  Female         Mrs
# 7              8  Bhubaneshwar  Female         Mrs
# 8              9  Bhubaneshwar  Female         Mrs
# 9             10  Bhubaneshwar  Female         Mrs
# 10            11  Bhubaneshwar  Female         Mrs
# 11            12  Bhubaneshwar  Female         Mrs
# 12            13  Bhubaneshwar  Female         Mrs
# 13            14  Bhubaneshwar  Female         Mrs
# 14            15  Bhubaneshwar  Female         Mrs
# 15            16  Bhubaneshwar  Female         Mrs
# 16            17  Bhubaneshwar  Female         Mrs
# ...

# %%
df.tail()
# Out:
#        people_ID     Region Gender Designation                 Name Married  \
# 10709      22691  Bengaluru   Male          Mr               ashish      NO
# 10710      22692  Bengaluru   Male          Mr  mohd mujahid ansari     YES
# 10711      22693  Bengaluru   Male          Mr           munnakumar     YES
# 10712      22694  Bengaluru   Male          Mr              prakash     YES
# 10713      22695  Bengaluru   Male          Mr      mehboob mehandi      NO
#
#        Children     Occupation Mode_transport  cases/1M  ...    HBB d-dimer  \
# 10709       2.0       Business            Car         8  ...   24.0   209.0
# 10710       0.0  Manufacturing            Car         8  ...  134.0   211.0
# 10711       0.0          Clerk         Public         8  ...  151.0   296.0
# 10712       1.0          Legal           Walk         8  ...  110.0   253.0
# 10713       2.0       Business            Car         8  ...  134.0   201.0
#
# ...

# %% [markdown]
# # New Section

# %%
df.columns
# Out:
# Index(['people_ID', 'Region', 'Gender', 'Designation', 'Name', 'Married',
#        'Children', 'Occupation', 'Mode_transport', 'cases/1M', 'Deaths/1M',
#        'comorbidity', 'Age', 'Coma score', 'Pulmonary score',
#        'cardiological pressure', 'Diuresis', 'Platelets', 'HBB', 'd-dimer',
#        'Heart rate', 'HDL cholesterol', 'Charlson Index', 'Blood Glucose',
#        'Insurance', 'salary', 'FT/month', 'Infect_Prob'],
#       dtype='object')

# %%
df['people_ID'].isna().sum()
sns.distplot(df['people_ID'])

# %%
df['Region'].isna().sum()
# Out:
# 0

# %%
df['Gender'].isna().sum()
# Out:
# 0

# %%
df['Designation'].isna().sum()
# Out:
# 0

# %%
df["Name"].dropna(axis=0,inplace=True)

# %%
df['Name'].isnull().sum()
# Out:
# 0

# %%
df['Married'].isna().sum()
# Out:
# 0

# %%
df['Children'].isna().sum()

df['Children'].fillna(df['Children'].median(),inplace=True)

df['Children'].isna().sum()
print(sns.distplot(df['Children']))

sns.boxplot(df["Children"])
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.columns
# Out:
# Index(['people_ID', 'Region', 'Gender', 'Designation', 'Name', 'Married',
#        'Children', 'Occupation', 'Mode_transport', 'cases/1M', 'Deaths/1M',
#        'comorbidity', 'Age', 'Coma score', 'Pulmonary score',
#        'cardiological pressure', 'Diuresis', 'Platelets', 'HBB', 'd-dimer',
#        'Heart rate', 'HDL cholesterol', 'Charlson Index', 'Blood Glucose',
#        'Insurance', 'salary', 'FT/month', 'Infect_Prob'],
#       dtype='object')

# %%
df['Occupation'].isna().sum()
df['Occupation'].fillna(df['Occupation'].mode()[0],inplace=True)

# %%
df['Occupation'].isna().sum()
# Out:
# 0

# %%
df['Mode_transport'].isna().sum()
df['Mode_transport'].dropna(inplace=True)

df['Mode_transport'].isna().sum()
# Out:
# 0

# %%
df['cases/1M'].isna().sum()
sns.distplot(df['cases/1M'])
sns.boxplot(df["cases/1M"])
df['cases/1M'].describe()
# Out:
# count    10714.000000
# mean         3.285888
# std          2.721274
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          4.000000
# max          8.000000
# Name: cases/1M, dtype: float64

# %%
q=df['cases/1M'].quantile(0.99)
data_cleaned=df[df['cases/1M']<q]

# %%
df['Deaths/1M'].isna().sum()
sns.distplot(df['Deaths/1M'])

# %%
#sns.distplot(df['Deaths/1M'])
sns.boxplot(df["Deaths/1M"])

# %%
df['comorbidity'].isna().sum()

df['comorbidity'].unique()

df['comorbidity'].dropna(inplace=True)

df['comorbidity'].isna().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['people_ID', 'Region', 'Gender', 'Designation', 'Name', 'Married',
#        'Children', 'Occupation', 'Mode_transport', 'cases/1M', 'Deaths/1M',
#        'comorbidity', 'Age', 'Coma score', 'Pulmonary score',
#        'cardiological pressure', 'Diuresis', 'Platelets', 'HBB', 'd-dimer',
#        'Heart rate', 'HDL cholesterol', 'Charlson Index', 'Blood Glucose',
#        'Insurance', 'salary', 'FT/month', 'Infect_Prob'],
#       dtype='object')

# %%
df['Age'].isna().sum()
sns.distplot(df['Age'])

# %%
sns.boxplot(df["Age"])

# %%
df['Coma score'].isna().sum()
sns.distplot(df['Coma score'])

# %%
sns.boxplot(df["Coma score"])

# %%
df['Pulmonary score'].isna().sum()
# Out:
# 0

# %%
df['cardiological pressure'].isna().sum()
df['cardiological pressure'].fillna(df['cardiological pressure'].mode()[0],inplace=True)



df['cardiological pressure'].isna().sum()
# Out:
# 0

# %%
df['Diuresis'].isna().sum()
df['Diuresis'].fillna(df['Diuresis'].median(),inplace=True)



df['Diuresis'].isna().sum()
sns.distplot(df['Diuresis'])

# %%
sns.boxplot(df["Diuresis"])

# %%
df['Platelets'].isna().sum()
df[['Platelets']].describe()
df['Platelets'].fillna(df['Platelets'].median(),inplace=True)
df['Platelets'].isna().sum()

sns.distplot(df['Platelets'])

# %%
sns.boxplot(df["Platelets"])

# %%
df['HBB'].isna().sum()
df[['HBB']].describe()
df['HBB'].fillna(df['HBB'].median(),inplace=True)
df['HBB'].isna().sum()
sns.distplot(df['HBB'])

# %%
sns.boxplot(df["HBB"])

# %%
df['d-dimer'].isna().sum()
df[['d-dimer']].describe()
df['d-dimer'].fillna(df['d-dimer'].median(),inplace=True)
df['d-dimer'].isna().sum()
sns.distplot(df['d-dimer'])

# %%
sns.boxplot(df["d-dimer"])

# %%
df.columns
# Out:
# Index(['people_ID', 'Region', 'Gender', 'Designation', 'Name', 'Married',
#        'Children', 'Occupation', 'Mode_transport', 'cases/1M', 'Deaths/1M',
#        'comorbidity', 'Age', 'Coma score', 'Pulmonary score',
#        'cardiological pressure', 'Diuresis', 'Platelets', 'HBB', 'd-dimer',
#        'Heart rate', 'HDL cholesterol', 'Charlson Index', 'Blood Glucose',
#        'Insurance', 'salary', 'FT/month', 'Infect_Prob'],
#       dtype='object')

# %%
df['Heart rate'].isna().sum()
df[['Heart rate']].describe()
df['Heart rate'].fillna(df['Heart rate'].median(),inplace=True)
df['Heart rate'].isna().sum()
sns.distplot(df['Heart rate'])

# %%
sns.boxplot(df["Heart rate"])

# %%
df['HDL cholesterol'].isna().sum()
df[['HDL cholesterol']].describe()
df['HDL cholesterol'].fillna(df['HDL cholesterol'].median(),inplace=True)
df['HDL cholesterol'].isna().sum()
sns.distplot(df['HDL cholesterol'])

# %%
sns.boxplot(df["HDL cholesterol"])

# %%
df['Charlson Index'].isna().sum()
sns.distplot(df['Charlson Index'])

# %%
sns.boxplot(df["Charlson Index"])

# %%
df['Blood Glucose'].isna().sum()
sns.distplot(df['Blood Glucose'])

# %%
sns.boxplot(df["Blood Glucose"])

# %%
df['Insurance'].isna().sum()
df[['Insurance']].describe()
df['Insurance'].fillna(df['Insurance'].median(),inplace=True)
sns.distplot(df['Insurance'])

# %%
sns.boxplot(df["Insurance"])

# %%
df['salary'].isna().sum()

sns.distplot(df['salary'])

# %%
sns.boxplot(df["salary"])

# %%
df['FT/month'].isna().sum()
df['FT/month'].fillna(df['FT/month'].median(),inplace=True)

df['FT/month'].isna().sum()


sns.distplot(df['FT/month'])

# %%
sns.boxplot(df["FT/month"])

# %%
df['Infect_Prob'].isna().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# people_ID                 0
# Region                    0
# Gender                    0
# Designation               0
# Name                      0
# Married                   0
# Children                  0
# Occupation                0
# Mode_transport            0
# cases/1M                  0
# Deaths/1M                 0
# comorbidity               0
# Age                       0
# Coma score                0
# Pulmonary score           0
# cardiological pressure    0
# Diuresis                  0
# Platelets                 0
# HBB                       0
# d-dimer                   0
# Heart rate                0
# HDL cholesterol           0
# Charlson Index            0
# Blood Glucose             0
# Insurance                 0
# salary                    0
# FT/month                  0
# Infect_Prob               0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10465 entries, 0 to 10713
# Data columns (total 28 columns):
# people_ID                 10465 non-null int64
# Region                    10465 non-null object
# Gender                    10465 non-null object
# Designation               10465 non-null object
# Name                      10465 non-null object
# Married                   10465 non-null object
# Children                  10465 non-null float64
# Occupation                10465 non-null object
# Mode_transport            10465 non-null object
# cases/1M                  10465 non-null int64
# Deaths/1M                 10465 non-null int64
# comorbidity               10465 non-null object
# Age                       10465 non-null int64
# Coma score                10465 non-null int64
# Pulmonary score           10465 non-null object
# cardiological pressure    10465 non-null object
# Diuresis                  10465 non-null float64
# ...

# %%
df[["Diuresis"]]
# Out:
#        Diuresis
# 0         441.0
# 1         276.0
# 2         416.0
# 3         410.0
# 4         390.0
# 5         389.0
# 6         276.0
# 7         194.0
# 8         310.0
# 9         242.0
# 10        373.0
# 11        192.0
# 12        403.0
# 13        120.0
# 14        382.0
# 15        239.0
# 16        199.0
# 17        182.0
# 18        181.0
# 19        220.0
# 20        246.0
# 21        220.0
# 22        415.0
# 23        203.0
# 24        148.0
# 25        381.0
# 26        251.0
# 27        185.0
# 28        276.0
# 29        405.0
# ...         ...
# 10684     411.0
# 10685     124.0
# 10686     302.0
# 10687     426.0
# 10688     395.0
# 10689     388.0
# 10690     149.0
# 10691     418.0
# 10692     234.0
# 10693     159.0
# 10694     431.0
# 10695     248.0
# 10696     145.0
# 10697     276.0
# 10698     372.0
# 10699     347.0
# 10700     379.0
# 10701     256.0
# 10702     417.0
# 10703     389.0
# 10704     339.0
# 10705     276.0
# 10706     276.0
# ...

# %%
import pandas as pd
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
y=df['Infect_Prob']

# %%
for col in df.columns:
    print(col,len(df[col].unique()))
# Out:
# people_ID 10465
# Region 5
# Gender 2
# Designation 2
# Name 6175
# Married 2
# Children 3
# Occupation 9
# Mode_transport 3
# cases/1M 4
# Deaths/1M 3
# comorbidity 4
# Age 53
# Coma score 13
# Pulmonary score 4
# cardiological pressure 4
# Diuresis 341
# Platelets 146
# HBB 191
# d-dimer 151
# Heart rate 51
# HDL cholesterol 36
# Charlson Index 41
# Blood Glucose 5
# Insurance 48
# salary 21
# FT/month 3
# Infect_Prob 8480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10465 entries, 0 to 10713
# Data columns (total 28 columns):
# people_ID                 10465 non-null int64
# Region                    10465 non-null object
# Gender                    10465 non-null object
# Designation               10465 non-null object
# Name                      10465 non-null object
# Married                   10465 non-null object
# Children                  10465 non-null float64
# Occupation                10465 non-null object
# Mode_transport            10465 non-null object
# cases/1M                  10465 non-null int64
# Deaths/1M                 10465 non-null int64
# comorbidity               10465 non-null object
# Age                       10465 non-null int64
# Coma score                10465 non-null int64
# Pulmonary score           10465 non-null object
# cardiological pressure    10465 non-null object
# Diuresis                  10465 non-null float64
# ...

# %%
df.Region=pd.Categorical(df.Region)
df.Region=df.Region.cat.codes

# %%
df["Region"].unique()
# Out:
# array([1, 2, 3, 4, 0], dtype=int64)

# %%
df["Region"].unique()
# Out:
# array([1, 2, 3, 4, 0], dtype=int64)

# %%
df.Gender=pd.Categorical(df.Gender)
df.Gender=df.Gender.cat.codes
df["Gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Designation=pd.Categorical(df.Designation)
df.Designation=df.Designation.cat.codes
df["Designation"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Name=pd.Categorical(df.Name)
df.Name=df.Name.cat.codes
df["Name"].unique()
# Out:
# array([2645, 4311, 5622, ..., 2849, 3023, 2740], dtype=int64)

# %%
df.Married=pd.Categorical(df.Married)
df.Married=df.Married.cat.codes
df["Married"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.Occupation=pd.Categorical(df.Occupation)
df.Occupation=df.Occupation.cat.codes
df["Occupation"].unique()
# Out:
# array([4, 1, 3, 6, 2, 8, 5, 0, 7], dtype=int64)

# %%
df.Mode_transport=pd.Categorical(df.Mode_transport)
df.Mode_transport=df.Mode_transport.cat.codes
df["Mode_transport"].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
df.comorbidity=pd.Categorical(df.comorbidity)
df.comorbidity=df.comorbidity.cat.codes
df["comorbidity"].unique()
# Out:
# array([2, 1, 3, 0], dtype=int64)

# %%
df["Pulmonary score"].unique()
# Out:
# array(['<400', '<100', '<300', '<200'], dtype=object)

# %%
df["Pulmonary score"]=pd.Categorical(df["Pulmonary score"])
df["Pulmonary score"]=df["Pulmonary score"].cat.codes
df["Pulmonary score"].unique()
# Out:
# array([3, 0, 2, 1], dtype=int64)

# %%
df["cardiological pressure"]=pd.Categorical(df["cardiological pressure"])
df["cardiological pressure"]=df["cardiological pressure"].cat.codes
df["cardiological pressure"].unique()
# Out:
# array([1, 3, 0, 2], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10465 entries, 0 to 10713
# Data columns (total 28 columns):
# people_ID                 10465 non-null int64
# Region                    10465 non-null int8
# Gender                    10465 non-null int8
# Designation               10465 non-null int8
# Name                      10465 non-null int16
# Married                   10465 non-null int8
# Children                  10465 non-null float64
# Occupation                10465 non-null int8
# Mode_transport            10465 non-null int8
# cases/1M                  10465 non-null int64
# Deaths/1M                 10465 non-null int64
# comorbidity               10465 non-null int8
# Age                       10465 non-null int64
# Coma score                10465 non-null int64
# Pulmonary score           10465 non-null int8
# cardiological pressure    10465 non-null int8
# Diuresis                  10465 non-null float64
# Platelets                 10465 non-null float64
# ...

# %%
df.count()
# Out:
# people_ID                 10465
# Region                    10465
# Gender                    10465
# Designation               10465
# Name                      10465
# Married                   10465
# Children                  10465
# Occupation                10465
# Mode_transport            10465
# cases/1M                  10465
# Deaths/1M                 10465
# comorbidity               10465
# Age                       10465
# Coma score                10465
# Pulmonary score           10465
# cardiological pressure    10465
# Diuresis                  10465
# Platelets                 10465
# HBB                       10465
# d-dimer                   10465
# Heart rate                10465
# HDL cholesterol           10465
# Charlson Index            10465
# Blood Glucose             10465
# Insurance                 10465
# salary                    10465
# FT/month                  10465
# Infect_Prob               10465
# dtype: int64

# %%
x_train=df.drop(columns='Infect_Prob')

# %%
y_train=df["Infect_Prob"]

# %%
model_decision=DecisionTreeClassifier()

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

scaled_data=scalar.fit_transform(x_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int8, int16, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int8, int16, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn import utils
from sklearn import preprocessing



lab_enc = preprocessing.LabelEncoder()
y_train_encoded = lab_enc.fit_transform(y_train)
print(y_train_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(y_train_encoded))
# Out:
# [4884 6689 8454 ... 2823 7543 8449]
# continuous
# multiclass
# multiclass

# %%
model_decision.fit(scaled_data,y_train_encoded)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier(random_state=6)

# %%
ran.fit(scaled_data,y_train_encoded)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=6, verbose=0, warm_start=False)

# %%
df_test=pd.read_csv("Test_dataset.csv")
df_test
# Out:
#        people_ID              Region  Gender Designation  \
# 0           5942               Delhi  Female         Mrs
# 1          18664               Delhi    Male          Mr
# 2           5603               Delhi  Female         Mrs
# 3           5649               Delhi  Female         Mrs
# 4           5099               Delhi  Female         Mrs
# 5          18749               Delhi    Male          Mr
# 6           5228               Delhi  Female         Mrs
# 7           5559               Delhi  Female         Mrs
# 8           5220               Delhi  Female         Mrs
# 9           5476               Delhi  Female         Mrs
# 10          5260               Delhi  Female         Mrs
# 11         17638               Delhi    Male          Mr
# 12         18635               Delhi    Male          Mr
# 13         18794               Delhi    Male          Mr
# 14          5263               Delhi  Female         Mrs
# ...

# %%
df_test.isnull().sum()
# Out:
# people_ID                  0
# Region                     0
# Gender                     0
# Designation                0
# Name                      32
# Married                    0
# Children                   0
# Occupation                 0
# Mode_transport             0
# cases/1M                   0
# Deaths/1M                  0
# comorbidity                0
# Age                        0
# Coma score                 0
# Pulmonary score            0
# cardiological pressure     0
# Diuresis                   0
# Platelets                  0
# HBB                        0
# d-dimer                    0
# Heart rate                 0
# HDL cholesterol            0
# Charlson Index             0
# Blood Glucose              0
# Insurance                  0
# salary                     0
# FT/month                   0
# dtype: int64

# %%
df_test.dropna(inplace=True)

# %%
df_test.isnull().sum()
# Out:
# people_ID                 0
# Region                    0
# Gender                    0
# Designation               0
# Name                      0
# Married                   0
# Children                  0
# Occupation                0
# Mode_transport            0
# cases/1M                  0
# Deaths/1M                 0
# comorbidity               0
# Age                       0
# Coma score                0
# Pulmonary score           0
# cardiological pressure    0
# Diuresis                  0
# Platelets                 0
# HBB                       0
# d-dimer                   0
# Heart rate                0
# HDL cholesterol           0
# Charlson Index            0
# Blood Glucose             0
# Insurance                 0
# salary                    0
# FT/month                  0
# dtype: int64

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14466 entries, 0 to 14497
# Data columns (total 27 columns):
# people_ID                 14466 non-null int64
# Region                    14466 non-null object
# Gender                    14466 non-null object
# Designation               14466 non-null object
# Name                      14466 non-null object
# Married                   14466 non-null object
# Children                  14466 non-null int64
# Occupation                14466 non-null object
# Mode_transport            14466 non-null object
# cases/1M                  14466 non-null int64
# Deaths/1M                 14466 non-null int64
# comorbidity               14466 non-null object
# Age                       14466 non-null int64
# Coma score                14466 non-null int64
# Pulmonary score           14466 non-null object
# cardiological pressure    14466 non-null object
# Diuresis                  14466 non-null int64
# ...

# %%
df_test.Region=pd.Categorical(df_test.Region)
df_test.Region=df_test.Region.cat.codes

# %%
df_test.Gender=pd.Categorical(df_test.Gender)
df_test.Gender=df_test.Gender.cat.codes
df_test["Gender"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df_test.Designation=pd.Categorical(df_test.Designation)
df_test.Designation=df_test.Designation.cat.codes
df_test["Designation"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_test.Name=pd.Categorical(df_test.Name)
df_test.Name=df_test.Name.cat.codes
df_test["Name"].unique()
# Out:
# array([6849, 4322, 4635, ..., 1929, 7107, 4307], dtype=int64)

# %%
df_test.Married=pd.Categorical(df_test.Married)
df_test.Married=df_test.Married.cat.codes
df_test["Married"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_test.Occupation=pd.Categorical(df_test.Occupation)
df_test.Occupation=df_test.Occupation.cat.codes
df_test["Occupation"].unique()
# Out:
# array([3, 5, 8, 0, 6, 7, 2, 1, 4], dtype=int64)

# %%
df_test.Mode_transport=pd.Categorical(df_test.Mode_transport)
df_test.Mode_transport=df_test.Mode_transport.cat.codes
df_test["Mode_transport"].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
df_test.comorbidity=pd.Categorical(df_test.comorbidity)
df_test.comorbidity=df_test.comorbidity.cat.codes
df_test["comorbidity"].unique()
# Out:
# array([1, 3, 2, 0], dtype=int64)

# %%
df_test["Pulmonary score"]=pd.Categorical(df_test["Pulmonary score"])
df_test["Pulmonary score"]=df_test["Pulmonary score"].cat.codes
df_test["Pulmonary score"].unique()
# Out:
# array([1, 0, 2, 3], dtype=int64)

# %%
df_test["cardiological pressure"]=pd.Categorical(df_test["cardiological pressure"])
df_test["cardiological pressure"]=df_test["cardiological pressure"].cat.codes
df_test["cardiological pressure"].unique()
# Out:
# array([2, 3, 0, 1], dtype=int64)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14498 entries, 0 to 14497
# Data columns (total 27 columns):
# people_ID                 14498 non-null int64
# Region                    14498 non-null int8
# Gender                    14498 non-null int8
# Designation               14498 non-null int8
# Name                      14498 non-null int16
# Married                   14498 non-null int8
# Children                  14498 non-null int64
# Occupation                14498 non-null int8
# Mode_transport            14498 non-null int8
# cases/1M                  14498 non-null int64
# Deaths/1M                 14498 non-null int64
# comorbidity               14498 non-null int8
# Age                       14498 non-null int64
# Coma score                14498 non-null int64
# Pulmonary score           14498 non-null int8
# cardiological pressure    14498 non-null int8
# Diuresis                  14498 non-null int64
# Platelets                 14498 non-null int64
# ...

# %%
df_test
model_test_decision=DecisionTreeClassifier()

# %%
test_prediction=model_decision.predict(df_test)
test_prediction
# Out:
# array([8353, 8353, 8353, ..., 4247, 4247, 4247], dtype=int64)

# %%
test_prediction.shape
# Out:
# (14498,)

# %%
pred=pd.DataFrame(test_prediction)
pred
# Out:
#           0
# 0      8353
# 1      8353
# 2      8353
# 3      8353
# 4      8353
# 5      8353
# 6      8353
# 7      8353
# 8      8353
# 9      8353
# 10     8353
# 11     8353
# 12     8353
# 13     7885
# 14     7885
# 15     7885
# 16     8353
# 17     8353
# 18     8353
# 19     8353
# 20     7885
# 21     7885
# 22     8353
# 23     8353
# 24     8353
# 25     8353
# 26     8353
# 27     7885
# 28     8353
# 29     8353
# ...     ...
# 14468  4247
# 14469  4247
# 14470  4247
# 14471  4247
# 14472  4247
# 14473  4247
# 14474  4247
# 14475  4247
# 14476  4247
# 14477  4247
# 14478  4247
# 14479  4247
# 14480  4247
# 14481  4247
# 14482  4247
# 14483  4247
# 14484  4247
# 14485  4247
# 14486  4247
# 14487  4247
# 14488  4247
# 14489  4247
# 14490  4247
# 14491  4247
# 14492  4247
# 14493  4247
# 14494  4247
# 14495  4247
# 14496  4247
# 14497  4247
#
# [14498 rows x 1 columns]

# %%
pred_ran=ran.predict(df_test)

# %%
Infect_Prob=pd.DataFrame(pred_ran)

Infect_Prob
# Out:
#           0
# 0      2326
# 1      2326
# 2      2326
# 3      2326
# 4      2326
# 5      2326
# 6      2326
# 7      2326
# 8      2326
# 9      2326
# 10     2326
# 11     2326
# 12     2326
# 13     1380
# 14     1380
# 15     1380
# 16     2326
# 17     2326
# 18     2326
# 19     2326
# 20     1380
# 21     1380
# 22     2326
# 23     2326
# 24     2326
# 25     2326
# 26     2326
# 27     1380
# 28     2326
# 29     2326
# ...     ...
# 14468  2326
# 14469  2326
# 14470  2326
# 14471  2326
# 14472  1380
# 14473  1380
# 14474  1380
# 14475  2326
# 14476  1380
# 14477  2326
# 14478  1380
# 14479  2326
# 14480  1380
# 14481  1380
# 14482  1380
# 14483  1380
# 14484  1380
# 14485  2326
# 14486  2326
# 14487  1380
# 14488  2326
# 14489  2326
# 14490  1380
# 14491  2326
# 14492  2326
# 14493  2326
# 14494  2326
# 14495  2326
# 14496  2326
# 14497  1380
#
# [14498 rows x 1 columns]

# %%
df_test[["people_ID"]]
pd.DataFrame(pred_ran)
dataset=pd.concat([df_test[["people_ID"]],Infect_Prob],axis=1)
dataset=dataset.rename(columns={'0':"Infect_Prob"})
dataset.columns=["people_ID","infect_prob"]

dataset.to_csv('submission_hemanth.csv',index=False)

# %%
df_test
# Out:
#        people_ID  Region  Gender  Designation  Name  Married  Children  \
# 0           5942       0       0            1  6849        1         2
# 1          18664       0       1            0  4322        1         2
# 2           5603       0       0            1  4635        1         2
# 3           5649       0       0            1  4661        1         2
# 4           5099       0       0            1   461        1         2
# 5          18749       0       1            0  1563        1         2
# 6           5228       0       0            1  7316        1         2
# 7           5559       0       0            1  1753        1         2
# 8           5220       0       0            1  5621        1         2
# 9           5476       0       0            1  4685        1         2
# 10          5260       0       0            1  2021        1         2
# 11         17638       0       1            0    32        1         2
# ...
